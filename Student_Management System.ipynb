# %%
Student_Name = [
    "Ersel Şimşek", "Tuncay Şanlı", "Dirk Kuyt", "Diego Lugano",
    "Alex De Souza"
]

courses = ['R', 'Python', 'C', 'Matlab', 'VBA']

students = {
    1: {
        'name': 'Ersel Şimşek',
        'course': 'Matlab',
        'midterm': 30,
        'final': 40,
        'project': 25
    },
    2: {
        'name': 'Tuncay Şanlı',
        'course': 'C',
        'midterm': 40,
        'final': 90,
        'project': 50
    },
    3: {
        'name': 'Dirk Kuyt',
        'course': 'R',
        'midterm': 90,
        'final': 80,
        'project': 30
    },
    4: {
        'name': 'Diego Lugano',
        'course': 'VBA',
        'midterm': 50,
        'final': 75,
        'project': 60
    },
    5: {
        'name': 'Alex De Souza',
        'course': 'Phyton',
        'midterm': 100,
        'final': 90,
        'project': 100
    },
}

check = 1 #check=0 olduğu durumlarda aynı seviyede yer alan aşağıdaki kodların çalışmaması için yazılmıştır.

for i in range(3):
    isim = input('Enter Name & Surname: ')
    if isim in Student_Name:
        print('Welcome')
        break
else:
    print("try again later")
    check = 0
x = 0
y = 0
courses_taken = []


def askit():
    global x
    x = int(input("how many courses did you take? "))
    return x


if check == 1:
    askit()


def ifpassed(x):
    if x < 3:
        print("You failed in class")

    else:
        global y
        
        global courses_taken
        while y<x:
            a=y+1
            lesson = input('Write the course %s:'%a)
            if lesson in courses and lesson not in courses_taken:
                courses_taken.append(lesson)
                
                y = y + 1
            else:
                print(
                    "Wrong Entry. Try again..."
                )
        print("The courses you have taken ", courses_taken)


if check == 1:
    ifpassed(x)

sonuc = 0

if courses_taken == []:
    print(" ")
else:
    for i in range(1, len(students.keys())):
        if isim == students[i]["name"] and students[i]["course"] in courses_taken:

            sonuc = students[i]["midterm"] * 0.3 + students[i][
                "final"] * 0.5 + students[i]["project"] * 0.2
            if sonuc > 90:
                print('Your score in %s lesson: AA'%students[i]["course"])
            elif 70 < sonuc < 90:
                print('Your score  in %s lesson: BB'%students[i]["course"])
            elif 50 < sonuc < 70:
                print('Your score in %s lesson : CC' %students[i]["course"])
            elif 30 < sonuc < 50:
                print('Your score in %s lesson: DD'%students[i]["course"])
            else:
                print('Your score in %s lesson: FF and  YOU FAILED IN COURSE'%students[i]["course"])
        elif isim == students[i]["name"] and students[i]["course"] not in courses_taken:
          print("None of the courses you entered doesn't match with the course you took exam. Try again.")
        else:
            i = i + 1
